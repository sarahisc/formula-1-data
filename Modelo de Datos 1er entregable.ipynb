# %%
import requests
import json
import pandas as pd 
import warnings
import numpy as np
warnings.filterwarnings("ignore")

# %% [markdown]
# # Tabla drivers

# %%
url = 'http://ergast.com/api/f1/drivers.json'
response = requests.get(url)
content=json.loads(response.content)

# %%
content['MRData']['DriverTable']['Drivers']
# Out:
# [{'driverId': 'abate',
#   'url': 'http://en.wikipedia.org/wiki/Carlo_Mario_Abate',
#   'givenName': 'Carlo',
#   'familyName': 'Abate',
#   'dateOfBirth': '1932-07-10',
#   'nationality': 'Italian'},
#  {'driverId': 'abecassis',
#   'url': 'http://en.wikipedia.org/wiki/George_Abecassis',
#   'givenName': 'George',
#   'familyName': 'Abecassis',
#   'dateOfBirth': '1913-03-21',
#   'nationality': 'British'},
#  {'driverId': 'acheson',
#   'url': 'http://en.wikipedia.org/wiki/Kenny_Acheson',
#   'givenName': 'Kenny',
#   'familyName': 'Acheson',
#   'dateOfBirth': '1957-11-27',
#   'nationality': 'British'},
#  {'driverId': 'adams',
#   'url': 'http://en.wikipedia.org/wiki/Philippe_Adams',
#   'givenName': 'Philippe',
#   'familyName': 'Adams',
#   'dateOfBirth': '1969-11-19',
#   'nationality': 'Belgian'},
#  {'driverId': 'ader',
#   'url': 'http://en.wikipedia.org/wiki/Walt_Ader',
#   'givenName': 'Walt',
#   'familyName': 'Ader',
#   'dateOfBirth': '1913-12-15',
# ...

# %%
driverinfo= {'driverID':[],'url':[],'givenName':[],'familyName':[],'dateOfBirth':[],'nationality':[]}

for year in list(range(2010,2023)):
    url='http://ergast.com/api/f1/{}/drivers.json'
    response = requests.get(url.format(year))
    content=json.loads(response.content)
    for item in content['MRData']['DriverTable']['Drivers']:
        driverinfo['driverID'].append(item['driverId'])
        driverinfo['url'].append(item['url'])
        driverinfo['givenName'].append(item['givenName'])
        driverinfo['familyName'].append(item['familyName'])
        driverinfo['dateOfBirth'].append(item['dateOfBirth'])
        driverinfo['nationality'].append(item['nationality'])
        
pd.DataFrame(driverinfo).to_csv('Drivers.csv', index= False)

# %% [markdown]
# # Tabla constructors

# %%
url = 'http://ergast.com/api/f1/constructors.json'
response = requests.get(url)
content=json.loads(response.content)

# %%
content['MRData']['ConstructorTable']['Constructors']
# Out:
# [{'constructorId': 'adams',
#   'url': 'http://en.wikipedia.org/wiki/Adams_(constructor)',
#   'name': 'Adams',
#   'nationality': 'American'},
#  {'constructorId': 'afm',
#   'url': 'http://en.wikipedia.org/wiki/Alex_von_Falkenhausen_Motorenbau',
#   'name': 'AFM',
#   'nationality': 'German'},
#  {'constructorId': 'ags',
#   'url': 'http://en.wikipedia.org/wiki/Automobiles_Gonfaronnaises_Sportives',
#   'name': 'AGS',
#   'nationality': 'French'},
#  {'constructorId': 'alfa',
#   'url': 'http://en.wikipedia.org/wiki/Alfa_Romeo_in_Formula_One',
#   'name': 'Alfa Romeo',
#   'nationality': 'Swiss'},
#  {'constructorId': 'alphatauri',
#   'url': 'http://en.wikipedia.org/wiki/Scuderia_AlphaTauri',
#   'name': 'AlphaTauri',
#   'nationality': 'Italian'},
#  {'constructorId': 'alpine',
#   'url': 'http://en.wikipedia.org/wiki/Alpine_F1_Team',
#   'name': 'Alpine F1 Team',
#   'nationality': 'French'},
#  {'constructorId': 'alta',
# ...

# %%
cons={'consID':[],'url':[],'Name':[],'Nationality':[]}
for year in list(range(2010,2023)):
    url='http://ergast.com/api/f1/{}/constructors.json'
    response = requests.get(url.format(year))
    content=json.loads(response.content)
    for item in content['MRData']['ConstructorTable']['Constructors']:
        cons['consID'].append(item['constructorId'])
        cons['url'].append(item['url'])
        cons['Name'].append(item['name'])
        cons['Nationality'].append(item['nationality'])

# %%
pd.DataFrame(cons).to_csv('Constructors.csv', index=False)

# %% [markdown]
# # Tabla Circuits

# %%
url='http://ergast.com/api/f1/circuits.json'
response = requests.get(url.format(year))
content=json.loads(response.content)

# %%
content['MRData']['CircuitTable']['Circuits']
# Out:
# [{'circuitId': 'adelaide',
#   'url': 'http://en.wikipedia.org/wiki/Adelaide_Street_Circuit',
#   'circuitName': 'Adelaide Street Circuit',
#   'Location': {'lat': '-34.9272',
#    'long': '138.617',
#    'locality': 'Adelaide',
#    'country': 'Australia'}},
#  {'circuitId': 'ain-diab',
#   'url': 'http://en.wikipedia.org/wiki/Ain-Diab_Circuit',
#   'circuitName': 'Ain Diab',
#   'Location': {'lat': '33.5786',
#    'long': '-7.6875',
#    'locality': 'Casablanca',
#    'country': 'Morocco'}},
#  {'circuitId': 'aintree',
#   'url': 'http://en.wikipedia.org/wiki/Aintree_Motor_Racing_Circuit',
#   'circuitName': 'Aintree',
#   'Location': {'lat': '53.4769',
#    'long': '-2.94056',
#    'locality': 'Liverpool',
#    'country': 'UK'}},
#  {'circuitId': 'albert_park',
#   'url': 'http://en.wikipedia.org/wiki/Melbourne_Grand_Prix_Circuit',
#   'circuitName': 'Albert Park Grand Prix Circuit',
#   'Location': {'lat': '-37.8497',
#    'long': '144.968',
#    'locality': 'Melbourne',
# ...

# %%
cir={'cirID':[],'url':[],'cirName':[],'Lat':[],'Long':[],'Locality':[],'Country':[]}
for year in list(range(2010,2023)):
    url='http://ergast.com/api/f1/{}/circuits.json'
    response = requests.get(url.format(year))
    content=json.loads(response.content)
    for item in content['MRData']['CircuitTable']['Circuits']:
        cir['cirID'].append(item['circuitId'])
        cir['url'].append(item['url'])
        cir['cirName'].append(item['circuitName'])
        cir['Lat'].append(item['Location']['lat'])
        cir['Long'].append(item['Location']['long'])
        cir['Locality'].append(item['Location']['locality'])
        cir['Country'].append(item['Location']['country'])
        
pd.DataFrame(cir).to_csv('Circuits.csv', index=False)

# %% [markdown]
# # Tabla qualifying

# %%
url='http://ergast.com/api/f1/qualifying.json'
response = requests.get(url)
content=json.loads(response.content)

# %%
content['MRData']['RaceTable']['Races'][1]['QualifyingResults']
# Out:
# [{'number': '2',
#   'position': '1',
#   'Driver': {'driverId': 'senna',
#    'url': 'http://en.wikipedia.org/wiki/Ayrton_Senna',
#    'givenName': 'Ayrton',
#    'familyName': 'Senna',
#    'dateOfBirth': '1960-03-21',
#    'nationality': 'Brazilian'},
#   'Constructor': {'constructorId': 'williams',
#    'url': 'http://en.wikipedia.org/wiki/Williams_Grand_Prix_Engineering',
#    'name': 'Williams',
#    'nationality': 'British'},
#   'Q1': '1:10.218'},
#  {'number': '5',
#   'position': '2',
#   'Driver': {'driverId': 'michael_schumacher',
#    'code': 'MSC',
#    'url': 'http://en.wikipedia.org/wiki/Michael_Schumacher',
#    'givenName': 'Michael',
#    'familyName': 'Schumacher',
#    'dateOfBirth': '1969-01-03',
#    'nationality': 'German'},
#   'Constructor': {'constructorId': 'benetton',
#    'url': 'http://en.wikipedia.org/wiki/Benetton_Formula',
#    'name': 'Benetton',
#    'nationality': 'Italian'},
#   'Q1': '1:10.440'},
#  {'number': '0',
#   'position': '3',
# ...

# %%
qua={'raceID':[],'num':[],'pos':[],'DriverID':[],'ConstructorID':[],'q1':[],'q2':[],'q3':[] }
for year in list(range(2010,2023)):
    url='http://ergast.com/api/f1/{}/qualifying.json'
    response = requests.get(url.format(year))
    content=json.loads(response.content)
    for item in content['MRData']['RaceTable']['Races'][0]['QualifyingResults']:
        qua['raceID'].append(content['MRData']['RaceTable']['Races'][0]['raceName'])
        qua['num'].append(item['number'])
        qua['pos'].append(item['position'])
        qua['DriverID'].append(item['Driver']['driverId'])
        qua['ConstructorID'].append(item['Constructor']['constructorId'])
        qua['q1'].append(item['Q1'])
        try:
            qua['q2'].append(item['Q2'])
        except:
            qua['q2'].append(np.nan)
        try:
            qua['q3'].append(item['Q3'])
        except:
            qua['q3'].append(np.nan)   
    for item in content['MRData']['RaceTable']['Races'][1]['QualifyingResults']:
        qua['raceID'].append(content['MRData']['RaceTable']['Races'][1]['raceName'])
        qua['num'].append(item['number'])
        qua['pos'].append(item['position'])
        qua['DriverID'].append(item['Driver']['driverId'])
        qua['ConstructorID'].append(item['Constructor']['constructorId'])
        qua['q1'].append(item['Q1'])
        qua['q2'].append(item['Q2'])
        try:
            qua['q3'].append(item['Q3'])
        except:
            qua['q3'].append(np.nan)

# %%
pd.DataFrame(qua).to_csv('Qualifying.csv', index=False)
